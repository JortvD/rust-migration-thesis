# %%
import json

with open("results.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Print the number of repositories in the results
print(len(data))
# Out:
# Rate limited (1762877219). Sleeping until reset (43s)...
